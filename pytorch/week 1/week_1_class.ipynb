# %%
import torch
import torch.nn as nn
import torch.optim as optim

# distance in miles
distance = torch.tensor([[1.0], [2.0], [3.0], [4.0]], dtype = torch.float32)
# delivery in minutes
times = torch.tensor([[6.92], [12.11], [16.77], [22.21]], dtype = torch.float32)

# brackets tell pytorch when one batch ends and another one begins even when we have several features for one batch

# create the neural network--> sequential is the way to create easy layers in pytorch

# Define the model

model = nn.Sequential(nn.Linear(1,1))

# sequential makes it easy for us to swap components
# this is a linear layer that takes one input and produces one output

# now define the loss function and optimizer

loss_function = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr = 0.01)
