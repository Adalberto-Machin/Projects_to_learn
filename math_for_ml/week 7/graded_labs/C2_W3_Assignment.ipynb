# %% [markdown]
# # Neural Network with Two Layers
#
# Welcome to your week three programming assignment. You are ready to build a neural network with two layers and train it to solve a classification problem.
#
# **After this assignment, you will be able to:**
#
# - Implement a neural network with two layers to a classification problem
# - Implement forward propagation using matrix multiplication
# - Perform backward propagation

# %% [markdown]
# # Table of Contents
#
# - [ 1 - Classification Problem](#1)
# - [ 2 - Neural Network Model with Two Layers](#2)
#   - [ 2.1 - Neural Network Model with Two Layers for a Single Training Example](#2.1)
#   - [ 2.2 - Neural Network Model with Two Layers for Multiple Training Examples](#2.2)
#   - [ 2.3 - Cost Function and Training](#2.3)
#   - [ 2.4 - Dataset](#2.4)
#   - [ 2.5 - Define Activation Function](#2.5)
#     - [ Exercise 1](#ex01)
# - [ 3 - Implementation of the Neural Network Model with Two Layers](#3)
#   - [ 3.1 - Defining the Neural Network Structure](#3.1)
#     - [ Exercise 2](#ex02)
#   - [ 3.2 - Initialize the Model's Parameters](#3.2)
#     - [ Exercise 3](#ex03)
#   - [ 3.3 - The Loop](#3.3)
#     - [ Exercise 4](#ex04)
#     - [ Exercise 5](#ex05)
#     - [ Exercise 6](#ex06)
#   - [ 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()](#3.4)
#     - [ Exercise 7](#ex07)
#     - [ Exercise 8](#ex08)
# - [ 4 - Optional: Other Dataset](#4)

# %% [markdown]
# ## Packages
#
# First, import all the packages you will need during this assignment.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# Load the unit tests defined for this notebook.

# %%
import w3_unittest

# %% [markdown]
# <a name='1'></a>
# ## 1 - Classification Problem

# %% [markdown]
# In one of the labs this week, you trained a neural network with a single perceptron, performing forward and backward propagation. That simple structure was enough to solve a "linear" classification problem - finding a straight line in a plane that would serve as a decision boundary to separate two classes.
#
# Imagine that now you have a more complicated problem: you still have two classes, but one line will not be enough to separate them.

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# This logic can appear in many applications. For example, if you train a model to predict whether you should buy a house knowing its size and the year it was built. A big new house will not be affordable, while a small old house will not be worth buying. So, you might be interested in either a big old house, or a small new house.
#
# The one perceptron neural network is not enough to solve such classification problem. Let's look at how you can adjust that model to find the solution.
#
# In the plot above, two lines can serve as a decision boundary. Your intuition might tell you that you should also increase the number of perceptrons. And that is absolutely right! You need to feed your data points (coordinates $x_1$, $x_2$) into two nodes separately and then unify them somehow with another one to make a decision.
#
# Now let's figure out the details, build and train your first multi-layer neural network!

# %% [markdown]
# <a name='2'></a>
# ## 2 - Neural Network Model with Two Layers

# %% [markdown]
# <a name='2.1'></a>
# ### 2.1 - Neural Network Model with Two Layers for a Single Training Example

# %% [markdown]
# <img src="images/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
#
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
#
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# &emsp; &emsp; $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# &emsp; &emsp; $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} =
# \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# &emsp; &emsp; $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.

# %% [markdown]
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
#
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
# &emsp; &emsp; $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# &emsp; &emsp; $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# Finally, the same sigmoid function is used as the output layer activation function:
#
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
#
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \tag{6}
# \end{align}
#
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.

# %% [markdown]
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5, \\ 0 & \mbox{otherwise }. \end{cases}$.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
#
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \tag{7}
# \end{align}
#
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
#
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
#
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
#
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
#
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \tag{9}
# \end{align}
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
#
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \tag{10}
# \end{align}

# %% [markdown]
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} =
# \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$

# %% [markdown]
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)=
# \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}
# \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix}
# =\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \end{bmatrix}$$.
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
#
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
#
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.

# %% [markdown]
# With the element by element multiplication,
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
#
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.

# %% [markdown]
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
#
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
#
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \tag{15}
# \end{align}
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.

# %% [markdown]
# So, to understand deeply and properly how neural networks perform and get trained, **you do need knowledge of linear algebra and calculus joined together**! But do not worry! All together it is not that scary if you do it step by step accurately with understanding of maths.
#
# Time to implement this all in the code!

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Dataset
#
# First, let's get the dataset you will work on. The following code will create $m=2000$ data points $(x_1, x_2)$ and save them in the `NumPy` array `X` of a shape $(2 \times m)$ (in the columns of the array). The labels ($0$: blue, $1$: red) will be saved in the `NumPy` array `Y` of a shape $(1 \times m)$.

# %%
m = 2000
samples, labels = make_blobs(n_samples=m, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Define Activation Function

# %% [markdown]
# <a name='ex01'></a>
# ### Exercise 1
#
# Define sigmoid activation function $\sigma\left(z\right) =\frac{1}{1+e^{-z}} $.

# %%
def sigmoid(z):
    ### START CODE HERE ### (~ 1 line of code)
    res = 1/(1+np.exp(-z))
    ### END CODE HERE ###
    
    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %% [markdown]
# ##### __Expected Output__
#
# Note: the values may vary in the last decimal places.
#
# ```Python
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436
# ```

# %%
w3_unittest.test_sigmoid(sigmoid)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3'></a>
# ## 3 - Implementation of the Neural Network Model with Two Layers

# %% [markdown]
# <a name='3.1'></a>
# ### 3.1 - Defining the Neural Network Structure

# %% [markdown]
# <a name='ex02'></a>
# ### Exercise 2
#
# Define three variables:
# - `n_x`: the size of the input layer
# - `n_h`: the size of the hidden layer (set it equal to 2 for now)
# - `n_y`: the size of the output layer

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hint</b></font>
# </summary>
# <p>
# <ul>
#     Use shapes of X and Y to find n_x and n_y:
#     <li>the size of the input layer n_x equals to the size of the input vectors placed in the columns of the array X,</li>
#     <li>the outpus for each of the data point will be saved in the columns of the the array Y.</li>
# </ul>
# </p>

# %%
# GRADED FUNCTION: layer_sizes

def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    ### START CODE HERE ### (~ 3 lines of code)
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0] 
    ### END CODE HERE ###
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1
# ```

# %%
w3_unittest.test_layer_sizes(layer_sizes)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.2'></a>
# ### 3.2 - Initialize the Model's Parameters

# %% [markdown]
# <a name='ex03'></a>
# ### Exercise 3
#
# Implement the function `initialize_parameters()`.
#
# **Instructions**:
# - Make sure your parameters' sizes are right. Refer to the neural network figure above if needed.
# - You will initialize the weights matrix with random values.
#     - Use: `np.random.randn(a,b) * 0.01` to randomly initialize a matrix of shape (a,b).
# - You will initialize the bias vector as zeros.
#     - Use: `np.zeros((a,b))` to initialize a matrix of shape (a,b) with zeros.

# %%
# GRADED FUNCTION: initialize_parameters

def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = np.random.randn(n_h,n_x)*0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y,n_h)*0.01
    b2 = np.zeros((n_y, 1))
    ### END CODE HERE ###
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.00881318  0.01709573]
#  [ 0.00050034 -0.00404677]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.0054536  -0.01546477]]
# b2 = [[0.]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different due to random initialization. You can try to restart the kernel to get the same values.
#
# ```Python
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_initialize_parameters(initialize_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.3'></a>
# ### 3.3 - The Loop

# %% [markdown]
# <a name='ex04'></a>
# ### Exercise 4
#
# Implement `forward_propagation()`.
#
# **Instructions**:
# - Look above at the mathematical representation $(7)$ of your classifier (section [2.2](#2.2)):
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Implement Forward Propagation. Compute `Z1` multiplying matrices `W1`, `X` and adding vector `b1`. Then find `A1` using the `sigmoid` activation function. Perform similar computations for `Z2` and `A2`.

# %%
# GRADED FUNCTION: forward_propagation

def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    ### END CODE HERE ###
    
    # Implement forward propagation to calculate A2.
    ### START CODE HERE ### (~ 4 lines of code)
    Z1 = W1@X + b1
    A1 = sigmoid(Z1)
    Z2 = W2@A1 + b2
    A2 = sigmoid(Z2)
    ### END CODE HERE ###
    
    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.4973606  0.49734242 0.49734535 ... 0.49737438 0.49736599 0.497345  ]]

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the array A2 maybe be different depending on the initial parameters. If you would like to get exactly the same output, try to restart the Kernel and rerun the notebook.
#
# ```Python
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_forward_propagation(forward_propagation)
# Out:
#  All tests passed

# %% [markdown]
# Remember, that your weights were just initialized with some random values, so the model has not been trained yet.

# %% [markdown]
# <a name='ex05'></a>
# ### Exercise 5
#
# Define a cost function $(8)$ which will be used to train the model:
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss
    
    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    cost -- log loss
    
    """
    # Number of examples.
    m = Y.shape[1]
    
    ### START CODE HERE ### (~ 2 lines of code)
    logloss = (1/m)*np.sum(-Y*np.log(A2) - (1-Y)*np.log(1-A2))
    cost = logloss
    ### END CODE HERE ###

    assert(isinstance(cost, float))
    
    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.693160921242041

# %% [markdown]
# ##### __Expected Output__
# Note: the elements of the arrays W1 and W2 maybe be different!
#
# ```Python
# cost = 0.6931477703826823
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_compute_cost(compute_cost, A2)
# Out:
# Test case "default_check". Wrong output of compute_cost.
# 	Expected:
# 0.6931477703826823
# 	Got:
# 0.693160921242041
#  1  Tests passed
#  1  Tests failed

# %% [markdown]
# Calculate partial derivatives as shown in $(15)$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)
    
    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]
    
    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]
    
    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-2.28666102e-05  4.68428161e-05]
#  [-4.99395041e-05  1.44687455e-04]]
# db1 = [[3.28788321e-06]
#  [1.02189007e-05]]
# dW2 = [[-0.00144492 -0.00128112]]
# db2 = [[-0.00264114]]

# %% [markdown]
# <a name='ex06'></a>
# ### Exercise 6
#
# Implement `update_parameters()`.
#
# **Instructions**:
# - Update parameters as shown in $(9)$ (section [2.3](#2.3)):
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}
# - The steps you have to implement are:
#     1. Retrieve each parameter from the dictionary "parameters" (which is the output of `initialize_parameters()`) by using `parameters[".."]`.
#     2. Retrieve each derivative from the dictionary "grads" (which is the output of `backward_propagation()`) by using `grads[".."]`.
#     3. Update parameters.

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule
    
    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent
    
    Returns:
    parameters -- python dictionary containing updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters".
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    ### END CODE HERE ###
    
    # Retrieve each gradient from the dictionary "grads".
    ### START CODE HERE ### (~ 4 lines of code)
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']


    ### END CODE HERE ###
    
    # Update rule for each parameter.
    ### START CODE HERE ### (~ 4 lines of code)
    W1 = W1 - learning_rate*dW1
    b1 = b1 - learning_rate*db1
    W2 = W2 - learning_rate*dW2
    b2 = b2 - learning_rate*db2
    ### END CODE HERE ###
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[ 0.00884062  0.01703952]
#  [ 0.00056026 -0.0042204 ]]
# b1 updated = [[-3.94545986e-06]
#  [-1.22626808e-05]]
# W2 updated = [[-0.00371969 -0.01392743]]
# b2 updated = [[0.00316937]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]
# ```

# %%
w3_unittest.test_update_parameters(update_parameters)
# Out:
#  All tests passed

# %% [markdown]
# <a name='3.4'></a>
# ### 3.4 - Integrate parts 3.1, 3.2 and 3.3 in nn_model()

# %% [markdown]
# <a name='ex07'></a>
# ### Exercise 7
#
# Build your neural network model in `nn_model()`.
#
# **Instructions**: The neural network model has to use the previous functions in the right order.

# %%
# GRADED FUNCTION: nn_model

def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    # Initialize parameters.
    ### START CODE HERE ### (~ 1 line of code)
    parameters = initialize_parameters(n_x, n_h, n_y)
    ### END CODE HERE ###
    
    # Loop.
    for i in range(0, num_iterations):
         
        ### START CODE HERE ### (~ 4 lines of code)
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)
        
        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)
        
        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)
        
        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate=1.2)
        ### END CODE HERE ###
        
        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693166
# Cost after iteration 1: 0.693154
# Cost after iteration 2: 0.693151
# Cost after iteration 3: 0.693149
# Cost after iteration 4: 0.693149
# Cost after iteration 5: 0.693149
# Cost after iteration 6: 0.693149
# Cost after iteration 7: 0.693149
# Cost after iteration 8: 0.693149
# Cost after iteration 9: 0.693149
# Cost after iteration 10: 0.693149
# Cost after iteration 11: 0.693148
# Cost after iteration 12: 0.693148
# Cost after iteration 13: 0.693148
# Cost after iteration 14: 0.693148
# Cost after iteration 15: 0.693148
# Cost after iteration 16: 0.693148
# Cost after iteration 17: 0.693148
# Cost after iteration 18: 0.693148
# Cost after iteration 19: 0.693148
# Cost after iteration 20: 0.693148
# Cost after iteration 21: 0.693148
# Cost after iteration 22: 0.693148
# Cost after iteration 23: 0.693148
# Cost after iteration 24: 0.693148
# Cost after iteration 25: 0.693148
# Cost after iteration 26: 0.693148
# Cost after iteration 27: 0.693148
# Cost after iteration 28: 0.693148
# Cost after iteration 29: 0.693148
# Cost after iteration 30: 0.693148
# Cost after iteration 31: 0.693148
# Cost after iteration 32: 0.693148
# Cost after iteration 33: 0.693148
# Cost after iteration 34: 0.693148
# Cost after iteration 35: 0.693148
# Cost after iteration 36: 0.693148
# Cost after iteration 37: 0.693148
# Cost after iteration 38: 0.693148
# Cost after iteration 39: 0.693148
# Cost after iteration 40: 0.693148
# Cost after iteration 41: 0.693148
# Cost after iteration 42: 0.693148
# Cost after iteration 43: 0.693147
# Cost after iteration 44: 0.693147
# Cost after iteration 45: 0.693147
# Cost after iteration 46: 0.693147
# Cost after iteration 47: 0.693147
# Cost after iteration 48: 0.693147
# Cost after iteration 49: 0.693147
# Cost after iteration 50: 0.693147
# Cost after iteration 51: 0.693147
# Cost after iteration 52: 0.693147
# Cost after iteration 53: 0.693147
# Cost after iteration 54: 0.693147
# Cost after iteration 55: 0.693147
# Cost after iteration 56: 0.693147
# Cost after iteration 57: 0.693147
# Cost after iteration 58: 0.693147
# Cost after iteration 59: 0.693147
# Cost after iteration 60: 0.693147
# Cost after iteration 61: 0.693147
# Cost after iteration 62: 0.693147
# Cost after iteration 63: 0.693147
# Cost after iteration 64: 0.693147
# Cost after iteration 65: 0.693147
# Cost after iteration 66: 0.693147
# Cost after iteration 67: 0.693147
# Cost after iteration 68: 0.693147
# Cost after iteration 69: 0.693147
# Cost after iteration 70: 0.693147
# Cost after iteration 71: 0.693147
# Cost after iteration 72: 0.693147
# Cost after iteration 73: 0.693147
# Cost after iteration 74: 0.693147
# Cost after iteration 75: 0.693147
# Cost after iteration 76: 0.693147
# Cost after iteration 77: 0.693146
# Cost after iteration 78: 0.693146
# Cost after iteration 79: 0.693146
# Cost after iteration 80: 0.693146
# Cost after iteration 81: 0.693146
# Cost after iteration 82: 0.693146
# Cost after iteration 83: 0.693146
# Cost after iteration 84: 0.693146
# Cost after iteration 85: 0.693146
# Cost after iteration 86: 0.693146
# Cost after iteration 87: 0.693146
# Cost after iteration 88: 0.693146
# Cost after iteration 89: 0.693146
# Cost after iteration 90: 0.693146
# Cost after iteration 91: 0.693146
# Cost after iteration 92: 0.693146
# Cost after iteration 93: 0.693146
# Cost after iteration 94: 0.693146
# Cost after iteration 95: 0.693146
# Cost after iteration 96: 0.693146
# Cost after iteration 97: 0.693146
# Cost after iteration 98: 0.693146
# Cost after iteration 99: 0.693146
# Cost after iteration 100: 0.693146
# Cost after iteration 101: 0.693146
# Cost after iteration 102: 0.693145
# Cost after iteration 103: 0.693145
# Cost after iteration 104: 0.693145
# Cost after iteration 105: 0.693145
# Cost after iteration 106: 0.693145
# Cost after iteration 107: 0.693145
# Cost after iteration 108: 0.693145
# Cost after iteration 109: 0.693145
# Cost after iteration 110: 0.693145
# Cost after iteration 111: 0.693145
# Cost after iteration 112: 0.693145
# Cost after iteration 113: 0.693145
# Cost after iteration 114: 0.693145
# Cost after iteration 115: 0.693145
# Cost after iteration 116: 0.693145
# Cost after iteration 117: 0.693145
# Cost after iteration 118: 0.693145
# Cost after iteration 119: 0.693145
# Cost after iteration 120: 0.693144
# Cost after iteration 121: 0.693144
# Cost after iteration 122: 0.693144
# Cost after iteration 123: 0.693144
# Cost after iteration 124: 0.693144
# Cost after iteration 125: 0.693144
# Cost after iteration 126: 0.693144
# Cost after iteration 127: 0.693144
# Cost after iteration 128: 0.693144
# Cost after iteration 129: 0.693144
# Cost after iteration 130: 0.693144
# Cost after iteration 131: 0.693144
# Cost after iteration 132: 0.693144
# Cost after iteration 133: 0.693144
# Cost after iteration 134: 0.693143
# Cost after iteration 135: 0.693143
# Cost after iteration 136: 0.693143
# Cost after iteration 137: 0.693143
# Cost after iteration 138: 0.693143
# Cost after iteration 139: 0.693143
# Cost after iteration 140: 0.693143
# Cost after iteration 141: 0.693143
# Cost after iteration 142: 0.693143
# Cost after iteration 143: 0.693143
# Cost after iteration 144: 0.693143
# Cost after iteration 145: 0.693142
# Cost after iteration 146: 0.693142
# Cost after iteration 147: 0.693142
# Cost after iteration 148: 0.693142
# Cost after iteration 149: 0.693142
# Cost after iteration 150: 0.693142
# Cost after iteration 151: 0.693142
# Cost after iteration 152: 0.693142
# Cost after iteration 153: 0.693142
# Cost after iteration 154: 0.693141
# Cost after iteration 155: 0.693141
# Cost after iteration 156: 0.693141
# Cost after iteration 157: 0.693141
# Cost after iteration 158: 0.693141
# Cost after iteration 159: 0.693141
# Cost after iteration 160: 0.693141
# Cost after iteration 161: 0.693140
# Cost after iteration 162: 0.693140
# Cost after iteration 163: 0.693140
# Cost after iteration 164: 0.693140
# Cost after iteration 165: 0.693140
# Cost after iteration 166: 0.693140
# Cost after iteration 167: 0.693140
# Cost after iteration 168: 0.693139
# Cost after iteration 169: 0.693139
# Cost after iteration 170: 0.693139
# Cost after iteration 171: 0.693139
# Cost after iteration 172: 0.693139
# Cost after iteration 173: 0.693138
# Cost after iteration 174: 0.693138
# Cost after iteration 175: 0.693138
# Cost after iteration 176: 0.693138
# Cost after iteration 177: 0.693138
# Cost after iteration 178: 0.693138
# Cost after iteration 179: 0.693137
# Cost after iteration 180: 0.693137
# Cost after iteration 181: 0.693137
# Cost after iteration 182: 0.693137
# Cost after iteration 183: 0.693136
# Cost after iteration 184: 0.693136
# Cost after iteration 185: 0.693136
# Cost after iteration 186: 0.693136
# Cost after iteration 187: 0.693135
# Cost after iteration 188: 0.693135
# Cost after iteration 189: 0.693135
# Cost after iteration 190: 0.693135
# Cost after iteration 191: 0.693134
# Cost after iteration 192: 0.693134
# Cost after iteration 193: 0.693134
# Cost after iteration 194: 0.693134
# Cost after iteration 195: 0.693133
# Cost after iteration 196: 0.693133
# Cost after iteration 197: 0.693133
# Cost after iteration 198: 0.693132
# Cost after iteration 199: 0.693132
# Cost after iteration 200: 0.693132
# Cost after iteration 201: 0.693131
# Cost after iteration 202: 0.693131
# Cost after iteration 203: 0.693131
# Cost after iteration 204: 0.693130
# Cost after iteration 205: 0.693130
# Cost after iteration 206: 0.693129
# Cost after iteration 207: 0.693129
# Cost after iteration 208: 0.693129
# Cost after iteration 209: 0.693128
# Cost after iteration 210: 0.693128
# Cost after iteration 211: 0.693127
# Cost after iteration 212: 0.693127
# Cost after iteration 213: 0.693126
# Cost after iteration 214: 0.693126
# Cost after iteration 215: 0.693126
# Cost after iteration 216: 0.693125
# Cost after iteration 217: 0.693125
# Cost after iteration 218: 0.693124
# Cost after iteration 219: 0.693123
# Cost after iteration 220: 0.693123
# Cost after iteration 221: 0.693122
# Cost after iteration 222: 0.693122
# Cost after iteration 223: 0.693121
# Cost after iteration 224: 0.693121
# Cost after iteration 225: 0.693120
# Cost after iteration 226: 0.693119
# Cost after iteration 227: 0.693119
# Cost after iteration 228: 0.693118
# Cost after iteration 229: 0.693117
# Cost after iteration 230: 0.693116
# Cost after iteration 231: 0.693116
# Cost after iteration 232: 0.693115
# Cost after iteration 233: 0.693114
# Cost after iteration 234: 0.693113
# Cost after iteration 235: 0.693112
# Cost after iteration 236: 0.693112
# Cost after iteration 237: 0.693111
# Cost after iteration 238: 0.693110
# Cost after iteration 239: 0.693109
# Cost after iteration 240: 0.693108
# Cost after iteration 241: 0.693107
# Cost after iteration 242: 0.693106
# Cost after iteration 243: 0.693104
# Cost after iteration 244: 0.693103
# Cost after iteration 245: 0.693102
# Cost after iteration 246: 0.693101
# Cost after iteration 247: 0.693100
# Cost after iteration 248: 0.693098
# Cost after iteration 249: 0.693097
# Cost after iteration 250: 0.693095
# Cost after iteration 251: 0.693094
# Cost after iteration 252: 0.693092
# Cost after iteration 253: 0.693091
# Cost after iteration 254: 0.693089
# Cost after iteration 255: 0.693087
# Cost after iteration 256: 0.693085
# Cost after iteration 257: 0.693083
# Cost after iteration 258: 0.693081
# Cost after iteration 259: 0.693079
# Cost after iteration 260: 0.693077
# Cost after iteration 261: 0.693074
# Cost after iteration 262: 0.693072
# Cost after iteration 263: 0.693069
# Cost after iteration 264: 0.693067
# Cost after iteration 265: 0.693064
# Cost after iteration 266: 0.693061
# Cost after iteration 267: 0.693057
# Cost after iteration 268: 0.693054
# Cost after iteration 269: 0.693050
# Cost after iteration 270: 0.693046
# Cost after iteration 271: 0.693042
# Cost after iteration 272: 0.693038
# Cost after iteration 273: 0.693033
# Cost after iteration 274: 0.693028
# Cost after iteration 275: 0.693023
# Cost after iteration 276: 0.693018
# Cost after iteration 277: 0.693012
# Cost after iteration 278: 0.693005
# Cost after iteration 279: 0.692998
# Cost after iteration 280: 0.692991
# Cost after iteration 281: 0.692982
# Cost after iteration 282: 0.692974
# Cost after iteration 283: 0.692964
# Cost after iteration 284: 0.692954
# Cost after iteration 285: 0.692943
# Cost after iteration 286: 0.692930
# Cost after iteration 287: 0.692917
# Cost after iteration 288: 0.692902
# Cost after iteration 289: 0.692886
# Cost after iteration 290: 0.692868
# Cost after iteration 291: 0.692848
# Cost after iteration 292: 0.692826
# Cost after iteration 293: 0.692802
# Cost after iteration 294: 0.692775
# Cost after iteration 295: 0.692744
# Cost after iteration 296: 0.692710
# Cost after iteration 297: 0.692672
# Cost after iteration 298: 0.692629
# Cost after iteration 299: 0.692579
# Cost after iteration 300: 0.692523
# Cost after iteration 301: 0.692460
# Cost after iteration 302: 0.692387
# Cost after iteration 303: 0.692302
# Cost after iteration 304: 0.692206
# Cost after iteration 305: 0.692093
# Cost after iteration 306: 0.691963
# Cost after iteration 307: 0.691811
# Cost after iteration 308: 0.691634
# Cost after iteration 309: 0.691427
# Cost after iteration 310: 0.691185
# Cost after iteration 311: 0.690900
# Cost after iteration 312: 0.690565
# Cost after iteration 313: 0.690171
# Cost after iteration 314: 0.689710
# Cost after iteration 315: 0.689169
# Cost after iteration 316: 0.688536
# Cost after iteration 317: 0.687799
# Cost after iteration 318: 0.686946
# Cost after iteration 319: 0.685963
# Cost after iteration 320: 0.684838
# Cost after iteration 321: 0.683561
# Cost after iteration 322: 0.682126
# Cost after iteration 323: 0.680527
# Cost after iteration 324: 0.678764
# Cost after iteration 325: 0.676840
# Cost after iteration 326: 0.674765
# Cost after iteration 327: 0.672547
# Cost after iteration 328: 0.670204
# Cost after iteration 329: 0.667750
# Cost after iteration 330: 0.665206
# Cost after iteration 331: 0.662590
# Cost after iteration 332: 0.659922
# Cost after iteration 333: 0.657220
# Cost after iteration 334: 0.654501
# Cost after iteration 335: 0.651781
# Cost after iteration 336: 0.649074
# Cost after iteration 337: 0.646391
# Cost after iteration 338: 0.643742
# Cost after iteration 339: 0.641136
# Cost after iteration 340: 0.638578
# Cost after iteration 341: 0.636072
# Cost after iteration 342: 0.633622
# Cost after iteration 343: 0.631229
# Cost after iteration 344: 0.628892
# Cost after iteration 345: 0.626612
# Cost after iteration 346: 0.624385
# Cost after iteration 347: 0.622210
# Cost after iteration 348: 0.620081
# Cost after iteration 349: 0.617995
# Cost after iteration 350: 0.615944
# Cost after iteration 351: 0.613922
# Cost after iteration 352: 0.611918
# Cost after iteration 353: 0.609922
# Cost after iteration 354: 0.607918
# Cost after iteration 355: 0.605887
# Cost after iteration 356: 0.603807
# Cost after iteration 357: 0.601650
# Cost after iteration 358: 0.599384
# Cost after iteration 359: 0.596971
# Cost after iteration 360: 0.594374
# Cost after iteration 361: 0.591554
# Cost after iteration 362: 0.588472
# Cost after iteration 363: 0.585093
# Cost after iteration 364: 0.581386
# Cost after iteration 365: 0.577332
# Cost after iteration 366: 0.572920
# Cost after iteration 367: 0.568154
# Cost after iteration 368: 0.563051
# Cost after iteration 369: 0.557638
# Cost after iteration 370: 0.551952
# Cost after iteration 371: 0.546035
# Cost after iteration 372: 0.539933
# Cost after iteration 373: 0.533691
# Cost after iteration 374: 0.527352
# Cost after iteration 375: 0.520955
# Cost after iteration 376: 0.514537
# Cost after iteration 377: 0.508130
# Cost after iteration 378: 0.501760
# Cost after iteration 379: 0.495450
# Cost after iteration 380: 0.489219
# Cost after iteration 381: 0.483084
# Cost after iteration 382: 0.477057
# Cost after iteration 383: 0.471146
# Cost after iteration 384: 0.465362
# Cost after iteration 385: 0.459707
# Cost after iteration 386: 0.454188
# Cost after iteration 387: 0.448805
# Cost after iteration 388: 0.443561
# Cost after iteration 389: 0.438456
# Cost after iteration 390: 0.433489
# Cost after iteration 391: 0.428660
# Cost after iteration 392: 0.423965
# Cost after iteration 393: 0.419404
# Cost after iteration 394: 0.414973
# Cost after iteration 395: 0.410669
# Cost after iteration 396: 0.406491
# Cost after iteration 397: 0.402434
# Cost after iteration 398: 0.398495
# Cost after iteration 399: 0.394670
# Cost after iteration 400: 0.390958
# Cost after iteration 401: 0.387353
# Cost after iteration 402: 0.383852
# Cost after iteration 403: 0.380452
# Cost after iteration 404: 0.377151
# Cost after iteration 405: 0.373943
# Cost after iteration 406: 0.370827
# Cost after iteration 407: 0.367799
# Cost after iteration 408: 0.364855
# Cost after iteration 409: 0.361994
# Cost after iteration 410: 0.359212
# Cost after iteration 411: 0.356506
# Cost after iteration 412: 0.353873
# Cost after iteration 413: 0.351311
# Cost after iteration 414: 0.348818
# Cost after iteration 415: 0.346390
# Cost after iteration 416: 0.344026
# Cost after iteration 417: 0.341723
# Cost after iteration 418: 0.339479
# Cost after iteration 419: 0.337291
# Cost after iteration 420: 0.335158
# Cost after iteration 421: 0.333078
# Cost after iteration 422: 0.331049
# Cost after iteration 423: 0.329069
# Cost after iteration 424: 0.327136
# Cost after iteration 425: 0.325249
# Cost after iteration 426: 0.323406
# Cost after iteration 427: 0.321605
# Cost after iteration 428: 0.319845
# Cost after iteration 429: 0.318124
# Cost after iteration 430: 0.316442
# Cost after iteration 431: 0.314796
# Cost after iteration 432: 0.313186
# Cost after iteration 433: 0.311609
# Cost after iteration 434: 0.310066
# Cost after iteration 435: 0.308555
# Cost after iteration 436: 0.307075
# Cost after iteration 437: 0.305624
# Cost after iteration 438: 0.304202
# Cost after iteration 439: 0.302808
# Cost after iteration 440: 0.301440
# Cost after iteration 441: 0.300099
# Cost after iteration 442: 0.298782
# Cost after iteration 443: 0.297490
# Cost after iteration 444: 0.296221
# Cost after iteration 445: 0.294975
# Cost after iteration 446: 0.293751
# Cost after iteration 447: 0.292548
# Cost after iteration 448: 0.291365
# Cost after iteration 449: 0.290202
# Cost after iteration 450: 0.289059
# Cost after iteration 451: 0.287934
# Cost after iteration 452: 0.286827
# Cost after iteration 453: 0.285738
# Cost after iteration 454: 0.284665
# Cost after iteration 455: 0.283609
# Cost after iteration 456: 0.282569
# Cost after iteration 457: 0.281544
# Cost after iteration 458: 0.280534
# Cost after iteration 459: 0.279539
# Cost after iteration 460: 0.278557
# Cost after iteration 461: 0.277590
# Cost after iteration 462: 0.276635
# Cost after iteration 463: 0.275693
# Cost after iteration 464: 0.274764
# Cost after iteration 465: 0.273847
# Cost after iteration 466: 0.272942
# Cost after iteration 467: 0.272048
# Cost after iteration 468: 0.271165
# Cost after iteration 469: 0.270293
# Cost after iteration 470: 0.269431
# Cost after iteration 471: 0.268580
# Cost after iteration 472: 0.267738
# Cost after iteration 473: 0.266906
# Cost after iteration 474: 0.266084
# Cost after iteration 475: 0.265271
# Cost after iteration 476: 0.264466
# Cost after iteration 477: 0.263671
# Cost after iteration 478: 0.262883
# Cost after iteration 479: 0.262105
# Cost after iteration 480: 0.261334
# Cost after iteration 481: 0.260571
# Cost after iteration 482: 0.259816
# Cost after iteration 483: 0.259068
# Cost after iteration 484: 0.258328
# Cost after iteration 485: 0.257594
# Cost after iteration 486: 0.256868
# Cost after iteration 487: 0.256149
# Cost after iteration 488: 0.255436
# Cost after iteration 489: 0.254730
# Cost after iteration 490: 0.254031
# Cost after iteration 491: 0.253338
# Cost after iteration 492: 0.252651
# Cost after iteration 493: 0.251970
# Cost after iteration 494: 0.251295
# Cost after iteration 495: 0.250626
# Cost after iteration 496: 0.249963
# Cost after iteration 497: 0.249305
# Cost after iteration 498: 0.248653
# Cost after iteration 499: 0.248007
# Cost after iteration 500: 0.247366
# Cost after iteration 501: 0.246730
# Cost after iteration 502: 0.246100
# Cost after iteration 503: 0.245475
# Cost after iteration 504: 0.244855
# Cost after iteration 505: 0.244240
# Cost after iteration 506: 0.243630
# Cost after iteration 507: 0.243025
# Cost after iteration 508: 0.242425
# Cost after iteration 509: 0.241830
# Cost after iteration 510: 0.241240
# Cost after iteration 511: 0.240654
# Cost after iteration 512: 0.240073
# Cost after iteration 513: 0.239497
# Cost after iteration 514: 0.238926
# Cost after iteration 515: 0.238359
# Cost after iteration 516: 0.237797
# Cost after iteration 517: 0.237239
# Cost after iteration 518: 0.236686
# Cost after iteration 519: 0.236137
# Cost after iteration 520: 0.235593
# Cost after iteration 521: 0.235054
# Cost after iteration 522: 0.234519
# Cost after iteration 523: 0.233988
# Cost after iteration 524: 0.233461
# Cost after iteration 525: 0.232939
# Cost after iteration 526: 0.232422
# Cost after iteration 527: 0.231909
# Cost after iteration 528: 0.231400
# Cost after iteration 529: 0.230895
# Cost after iteration 530: 0.230395
# Cost after iteration 531: 0.229899
# Cost after iteration 532: 0.229407
# Cost after iteration 533: 0.228920
# Cost after iteration 534: 0.228437
# Cost after iteration 535: 0.227958
# Cost after iteration 536: 0.227483
# Cost after iteration 537: 0.227013
# Cost after iteration 538: 0.226547
# Cost after iteration 539: 0.226085
# Cost after iteration 540: 0.225627
# Cost after iteration 541: 0.225173
# Cost after iteration 542: 0.224724
# Cost after iteration 543: 0.224279
# Cost after iteration 544: 0.223837
# Cost after iteration 545: 0.223400
# Cost after iteration 546: 0.222968
# Cost after iteration 547: 0.222539
# Cost after iteration 548: 0.222114
# Cost after iteration 549: 0.221693
# Cost after iteration 550: 0.221277
# Cost after iteration 551: 0.220864
# Cost after iteration 552: 0.220456
# Cost after iteration 553: 0.220051
# Cost after iteration 554: 0.219651
# Cost after iteration 555: 0.219254
# Cost after iteration 556: 0.218861
# Cost after iteration 557: 0.218473
# Cost after iteration 558: 0.218088
# Cost after iteration 559: 0.217707
# Cost after iteration 560: 0.217330
# Cost after iteration 561: 0.216956
# Cost after iteration 562: 0.216587
# Cost after iteration 563: 0.216221
# Cost after iteration 564: 0.215859
# Cost after iteration 565: 0.215501
# Cost after iteration 566: 0.215147
# Cost after iteration 567: 0.214796
# Cost after iteration 568: 0.214449
# Cost after iteration 569: 0.214105
# Cost after iteration 570: 0.213765
# Cost after iteration 571: 0.213429
# Cost after iteration 572: 0.213096
# Cost after iteration 573: 0.212767
# Cost after iteration 574: 0.212441
# Cost after iteration 575: 0.212119
# Cost after iteration 576: 0.211800
# Cost after iteration 577: 0.211484
# Cost after iteration 578: 0.211172
# Cost after iteration 579: 0.210864
# Cost after iteration 580: 0.210558
# Cost after iteration 581: 0.210256
# Cost after iteration 582: 0.209959
# Cost after iteration 583: 0.209671
# Cost after iteration 584: 0.209409
# Cost after iteration 585: 0.209244
# Cost after iteration 586: 0.209472
# Cost after iteration 587: 0.211356
# Cost after iteration 588: 0.220507
# Cost after iteration 589: 0.264420
# Cost after iteration 590: 0.485210
# Cost after iteration 591: 0.858826
# Cost after iteration 592: 1.287935
# Cost after iteration 593: 0.253832
# Cost after iteration 594: 0.230877
# Cost after iteration 595: 0.226050
# Cost after iteration 596: 0.223713
# Cost after iteration 597: 0.222382
# Cost after iteration 598: 0.221286
# Cost after iteration 599: 0.220317
# Cost after iteration 600: 0.219434
# Cost after iteration 601: 0.218622
# Cost after iteration 602: 0.217869
# Cost after iteration 603: 0.217167
# Cost after iteration 604: 0.216508
# Cost after iteration 605: 0.215888
# Cost after iteration 606: 0.215301
# Cost after iteration 607: 0.214743
# Cost after iteration 608: 0.214210
# Cost after iteration 609: 0.213700
# Cost after iteration 610: 0.213211
# Cost after iteration 611: 0.212739
# Cost after iteration 612: 0.212284
# Cost after iteration 613: 0.211844
# Cost after iteration 614: 0.211420
# Cost after iteration 615: 0.211009
# Cost after iteration 616: 0.210615
# Cost after iteration 617: 0.210235
# Cost after iteration 618: 0.209877
# Cost after iteration 619: 0.209538
# Cost after iteration 620: 0.209237
# Cost after iteration 621: 0.208968
# Cost after iteration 622: 0.208780
# Cost after iteration 623: 0.208653
# Cost after iteration 624: 0.208729
# Cost after iteration 625: 0.208934
# Cost after iteration 626: 0.209712
# Cost after iteration 627: 0.210740
# Cost after iteration 628: 0.213577
# Cost after iteration 629: 0.216610
# Cost after iteration 630: 0.225738
# Cost after iteration 631: 0.231716
# Cost after iteration 632: 0.256333
# Cost after iteration 633: 0.255329
# Cost after iteration 634: 0.298889
# Cost after iteration 635: 0.273139
# Cost after iteration 636: 0.315832
# Cost after iteration 637: 0.285699
# Cost after iteration 638: 0.332356
# Cost after iteration 639: 0.356520
# Cost after iteration 640: 0.451611
# Cost after iteration 641: 0.414351
# Cost after iteration 642: 0.391259
# Cost after iteration 643: 0.299599
# Cost after iteration 644: 0.256517
# Cost after iteration 645: 0.231613
# Cost after iteration 646: 0.221571
# Cost after iteration 647: 0.216920
# Cost after iteration 648: 0.215102
# Cost after iteration 649: 0.213504
# Cost after iteration 650: 0.212582
# Cost after iteration 651: 0.211738
# Cost after iteration 652: 0.211110
# Cost after iteration 653: 0.210527
# Cost after iteration 654: 0.210024
# Cost after iteration 655: 0.209544
# Cost after iteration 656: 0.209100
# Cost after iteration 657: 0.208669
# Cost after iteration 658: 0.208257
# Cost after iteration 659: 0.207854
# Cost after iteration 660: 0.207463
# Cost after iteration 661: 0.207078
# Cost after iteration 662: 0.206702
# Cost after iteration 663: 0.206332
# Cost after iteration 664: 0.205968
# Cost after iteration 665: 0.205610
# Cost after iteration 666: 0.205259
# Cost after iteration 667: 0.204912
# Cost after iteration 668: 0.204572
# Cost after iteration 669: 0.204236
# Cost after iteration 670: 0.203906
# Cost after iteration 671: 0.203582
# Cost after iteration 672: 0.203264
# Cost after iteration 673: 0.202950
# Cost after iteration 674: 0.202644
# Cost after iteration 675: 0.202343
# Cost after iteration 676: 0.202049
# Cost after iteration 677: 0.201762
# Cost after iteration 678: 0.201485
# Cost after iteration 679: 0.201216
# Cost after iteration 680: 0.200962
# Cost after iteration 681: 0.200719
# Cost after iteration 682: 0.200502
# Cost after iteration 683: 0.200304
# Cost after iteration 684: 0.200158
# Cost after iteration 685: 0.200050
# Cost after iteration 686: 0.200063
# Cost after iteration 687: 0.200159
# Cost after iteration 688: 0.200575
# Cost after iteration 689: 0.201176
# Cost after iteration 690: 0.202729
# Cost after iteration 691: 0.204688
# Cost after iteration 692: 0.209813
# Cost after iteration 693: 0.215413
# Cost after iteration 694: 0.232042
# Cost after iteration 695: 0.243909
# Cost after iteration 696: 0.292002
# Cost after iteration 697: 0.310873
# Cost after iteration 698: 0.457185
# Cost after iteration 699: 0.526083
# Cost after iteration 700: 0.870181
# Cost after iteration 701: 0.309022
# Cost after iteration 702: 0.268703
# Cost after iteration 703: 0.222391
# Cost after iteration 704: 0.213975
# Cost after iteration 705: 0.210466
# Cost after iteration 706: 0.208941
# Cost after iteration 707: 0.207990
# Cost after iteration 708: 0.207304
# Cost after iteration 709: 0.206719
# Cost after iteration 710: 0.206190
# Cost after iteration 711: 0.205695
# Cost after iteration 712: 0.205224
# Cost after iteration 713: 0.204772
# Cost after iteration 714: 0.204338
# Cost after iteration 715: 0.203918
# Cost after iteration 716: 0.203513
# Cost after iteration 717: 0.203119
# Cost after iteration 718: 0.202738
# Cost after iteration 719: 0.202367
# Cost after iteration 720: 0.202007
# Cost after iteration 721: 0.201656
# Cost after iteration 722: 0.201314
# Cost after iteration 723: 0.200981
# Cost after iteration 724: 0.200656
# Cost after iteration 725: 0.200339
# Cost after iteration 726: 0.200030
# Cost after iteration 727: 0.199727
# Cost after iteration 728: 0.199432
# Cost after iteration 729: 0.199143
# Cost after iteration 730: 0.198861
# Cost after iteration 731: 0.198585
# Cost after iteration 732: 0.198315
# Cost after iteration 733: 0.198051
# Cost after iteration 734: 0.197792
# Cost after iteration 735: 0.197540
# Cost after iteration 736: 0.197293
# Cost after iteration 737: 0.197051
# Cost after iteration 738: 0.196814
# Cost after iteration 739: 0.196583
# Cost after iteration 740: 0.196356
# Cost after iteration 741: 0.196135
# Cost after iteration 742: 0.195918
# Cost after iteration 743: 0.195706
# Cost after iteration 744: 0.195498
# Cost after iteration 745: 0.195295
# Cost after iteration 746: 0.195097
# Cost after iteration 747: 0.194903
# Cost after iteration 748: 0.194713
# Cost after iteration 749: 0.194527
# Cost after iteration 750: 0.194345
# Cost after iteration 751: 0.194167
# Cost after iteration 752: 0.193993
# Cost after iteration 753: 0.193822
# Cost after iteration 754: 0.193656
# Cost after iteration 755: 0.193493
# Cost after iteration 756: 0.193334
# Cost after iteration 757: 0.193179
# Cost after iteration 758: 0.193028
# Cost after iteration 759: 0.192881
# Cost after iteration 760: 0.192742
# Cost after iteration 761: 0.192614
# Cost after iteration 762: 0.192505
# Cost after iteration 763: 0.192437
# Cost after iteration 764: 0.192458
# Cost after iteration 765: 0.192673
# Cost after iteration 766: 0.193361
# Cost after iteration 767: 0.195117
# Cost after iteration 768: 0.199789
# Cost after iteration 769: 0.211467
# Cost after iteration 770: 0.247615
# Cost after iteration 771: 0.344910
# Cost after iteration 772: 0.582567
# Cost after iteration 773: 0.473459
# Cost after iteration 774: 0.600195
# Cost after iteration 775: 0.402770
# Cost after iteration 776: 0.512588
# Cost after iteration 777: 0.289069
# Cost after iteration 778: 0.272166
# Cost after iteration 779: 0.217549
# Cost after iteration 780: 0.211976
# Cost after iteration 781: 0.207263
# Cost after iteration 782: 0.205397
# Cost after iteration 783: 0.204015
# Cost after iteration 784: 0.203160
# Cost after iteration 785: 0.202471
# Cost after iteration 786: 0.201908
# Cost after iteration 787: 0.201404
# Cost after iteration 788: 0.200943
# Cost after iteration 789: 0.200509
# Cost after iteration 790: 0.200098
# Cost after iteration 791: 0.199705
# Cost after iteration 792: 0.199327
# Cost after iteration 793: 0.198963
# Cost after iteration 794: 0.198612
# Cost after iteration 795: 0.198273
# Cost after iteration 796: 0.197944
# Cost after iteration 797: 0.197625
# Cost after iteration 798: 0.197316
# Cost after iteration 799: 0.197017
# Cost after iteration 800: 0.196726
# Cost after iteration 801: 0.196443
# Cost after iteration 802: 0.196168
# Cost after iteration 803: 0.195901
# Cost after iteration 804: 0.195641
# Cost after iteration 805: 0.195388
# Cost after iteration 806: 0.195142
# Cost after iteration 807: 0.194903
# Cost after iteration 808: 0.194670
# Cost after iteration 809: 0.194443
# Cost after iteration 810: 0.194221
# Cost after iteration 811: 0.194006
# Cost after iteration 812: 0.193796
# Cost after iteration 813: 0.193592
# Cost after iteration 814: 0.193392
# Cost after iteration 815: 0.193198
# Cost after iteration 816: 0.193009
# Cost after iteration 817: 0.192825
# Cost after iteration 818: 0.192645
# Cost after iteration 819: 0.192470
# Cost after iteration 820: 0.192299
# Cost after iteration 821: 0.192133
# Cost after iteration 822: 0.191971
# Cost after iteration 823: 0.191813
# Cost after iteration 824: 0.191659
# Cost after iteration 825: 0.191509
# Cost after iteration 826: 0.191363
# Cost after iteration 827: 0.191220
# Cost after iteration 828: 0.191082
# Cost after iteration 829: 0.190947
# Cost after iteration 830: 0.190817
# Cost after iteration 831: 0.190691
# Cost after iteration 832: 0.190569
# Cost after iteration 833: 0.190454
# Cost after iteration 834: 0.190348
# Cost after iteration 835: 0.190253
# Cost after iteration 836: 0.190177
# Cost after iteration 837: 0.190132
# Cost after iteration 838: 0.190147
# Cost after iteration 839: 0.190256
# Cost after iteration 840: 0.190573
# Cost after iteration 841: 0.191218
# Cost after iteration 842: 0.192686
# Cost after iteration 843: 0.195394
# Cost after iteration 844: 0.201837
# Cost after iteration 845: 0.213713
# Cost after iteration 846: 0.247121
# Cost after iteration 847: 0.312945
# Cost after iteration 848: 0.546418
# Cost after iteration 849: 0.672837
# Cost after iteration 850: 1.560200
# Cost after iteration 851: 0.370284
# Cost after iteration 852: 0.227519
# Cost after iteration 853: 0.216407
# Cost after iteration 854: 0.213876
# Cost after iteration 855: 0.212154
# Cost after iteration 856: 0.210704
# Cost after iteration 857: 0.209403
# Cost after iteration 858: 0.208217
# Cost after iteration 859: 0.207128
# Cost after iteration 860: 0.206122
# Cost after iteration 861: 0.205192
# Cost after iteration 862: 0.204328
# Cost after iteration 863: 0.203524
# Cost after iteration 864: 0.202773
# Cost after iteration 865: 0.202072
# Cost after iteration 866: 0.201415
# Cost after iteration 867: 0.200798
# Cost after iteration 868: 0.200217
# Cost after iteration 869: 0.199671
# Cost after iteration 870: 0.199155
# Cost after iteration 871: 0.198668
# Cost after iteration 872: 0.198206
# Cost after iteration 873: 0.197769
# Cost after iteration 874: 0.197354
# Cost after iteration 875: 0.196959
# Cost after iteration 876: 0.196584
# Cost after iteration 877: 0.196226
# Cost after iteration 878: 0.195885
# Cost after iteration 879: 0.195559
# Cost after iteration 880: 0.195247
# Cost after iteration 881: 0.194949
# Cost after iteration 882: 0.194663
# Cost after iteration 883: 0.194389
# Cost after iteration 884: 0.194126
# Cost after iteration 885: 0.193874
# Cost after iteration 886: 0.193631
# Cost after iteration 887: 0.193397
# Cost after iteration 888: 0.193172
# Cost after iteration 889: 0.192955
# Cost after iteration 890: 0.192746
# Cost after iteration 891: 0.192544
# Cost after iteration 892: 0.192350
# Cost after iteration 893: 0.192162
# Cost after iteration 894: 0.191980
# Cost after iteration 895: 0.191804
# Cost after iteration 896: 0.191634
# Cost after iteration 897: 0.191469
# Cost after iteration 898: 0.191310
# Cost after iteration 899: 0.191155
# Cost after iteration 900: 0.191005
# Cost after iteration 901: 0.190860
# Cost after iteration 902: 0.190719
# Cost after iteration 903: 0.190583
# Cost after iteration 904: 0.190450
# Cost after iteration 905: 0.190322
# Cost after iteration 906: 0.190197
# Cost after iteration 907: 0.190075
# Cost after iteration 908: 0.189957
# Cost after iteration 909: 0.189842
# Cost after iteration 910: 0.189731
# Cost after iteration 911: 0.189622
# Cost after iteration 912: 0.189517
# Cost after iteration 913: 0.189414
# Cost after iteration 914: 0.189314
# Cost after iteration 915: 0.189217
# Cost after iteration 916: 0.189122
# Cost after iteration 917: 0.189029
# Cost after iteration 918: 0.188939
# Cost after iteration 919: 0.188851
# Cost after iteration 920: 0.188766
# Cost after iteration 921: 0.188682
# Cost after iteration 922: 0.188601
# Cost after iteration 923: 0.188521
# Cost after iteration 924: 0.188443
# Cost after iteration 925: 0.188368
# Cost after iteration 926: 0.188293
# Cost after iteration 927: 0.188221
# Cost after iteration 928: 0.188150
# Cost after iteration 929: 0.188081
# Cost after iteration 930: 0.188013
# Cost after iteration 931: 0.187947
# Cost after iteration 932: 0.187882
# Cost after iteration 933: 0.187819
# Cost after iteration 934: 0.187757
# Cost after iteration 935: 0.187696
# Cost after iteration 936: 0.187637
# Cost after iteration 937: 0.187578
# Cost after iteration 938: 0.187521
# Cost after iteration 939: 0.187465
# Cost after iteration 940: 0.187410
# Cost after iteration 941: 0.187356
# Cost after iteration 942: 0.187303
# Cost after iteration 943: 0.187251
# Cost after iteration 944: 0.187200
# Cost after iteration 945: 0.187150
# Cost after iteration 946: 0.187102
# Cost after iteration 947: 0.187055
# Cost after iteration 948: 0.187011
# Cost after iteration 949: 0.186972
# Cost after iteration 950: 0.186944
# Cost after iteration 951: 0.186940
# Cost after iteration 952: 0.186988
# Cost after iteration 953: 0.187158
# Cost after iteration 954: 0.187600
# Cost after iteration 955: 0.188736
# Cost after iteration 956: 0.191351
# Cost after iteration 957: 0.198322
# Cost after iteration 958: 0.214278
# Cost after iteration 959: 0.266824
# Cost after iteration 960: 0.393521
# Cost after iteration 961: 0.896695
# Cost after iteration 962: 0.596732
# Cost after iteration 963: 1.167899
# Cost after iteration 964: 0.317057
# Cost after iteration 965: 0.220132
# Cost after iteration 966: 0.210587
# Cost after iteration 967: 0.207046
# Cost after iteration 968: 0.205555
# Cost after iteration 969: 0.204420
# Cost after iteration 970: 0.203431
# Cost after iteration 971: 0.202527
# Cost after iteration 972: 0.201691
# Cost after iteration 973: 0.200914
# Cost after iteration 974: 0.200191
# Cost after iteration 975: 0.199516
# Cost after iteration 976: 0.198885
# Cost after iteration 977: 0.198294
# Cost after iteration 978: 0.197740
# Cost after iteration 979: 0.197221
# Cost after iteration 980: 0.196732
# Cost after iteration 981: 0.196273
# Cost after iteration 982: 0.195840
# Cost after iteration 983: 0.195432
# Cost after iteration 984: 0.195046
# Cost after iteration 985: 0.194682
# Cost after iteration 986: 0.194338
# Cost after iteration 987: 0.194011
# Cost after iteration 988: 0.193702
# Cost after iteration 989: 0.193409
# Cost after iteration 990: 0.193131
# Cost after iteration 991: 0.192866
# Cost after iteration 992: 0.192614
# Cost after iteration 993: 0.192374
# Cost after iteration 994: 0.192146
# Cost after iteration 995: 0.191928
# Cost after iteration 996: 0.191720
# Cost after iteration 997: 0.191521
# Cost after iteration 998: 0.191331
# Cost after iteration 999: 0.191149
# Cost after iteration 1000: 0.190974
# Cost after iteration 1001: 0.190807
# Cost after iteration 1002: 0.190647
# Cost after iteration 1003: 0.190493
# Cost after iteration 1004: 0.190345
# Cost after iteration 1005: 0.190203
# Cost after iteration 1006: 0.190066
# Cost after iteration 1007: 0.189934
# Cost after iteration 1008: 0.189807
# Cost after iteration 1009: 0.189685
# Cost after iteration 1010: 0.189567
# Cost after iteration 1011: 0.189453
# Cost after iteration 1012: 0.189343
# Cost after iteration 1013: 0.189236
# Cost after iteration 1014: 0.189133
# Cost after iteration 1015: 0.189033
# Cost after iteration 1016: 0.188937
# Cost after iteration 1017: 0.188843
# Cost after iteration 1018: 0.188753
# Cost after iteration 1019: 0.188665
# Cost after iteration 1020: 0.188579
# Cost after iteration 1021: 0.188496
# Cost after iteration 1022: 0.188416
# Cost after iteration 1023: 0.188337
# Cost after iteration 1024: 0.188261
# Cost after iteration 1025: 0.188187
# Cost after iteration 1026: 0.188115
# Cost after iteration 1027: 0.188044
# Cost after iteration 1028: 0.187976
# Cost after iteration 1029: 0.187909
# Cost after iteration 1030: 0.187844
# Cost after iteration 1031: 0.187780
# Cost after iteration 1032: 0.187718
# Cost after iteration 1033: 0.187658
# Cost after iteration 1034: 0.187599
# Cost after iteration 1035: 0.187541
# Cost after iteration 1036: 0.187484
# Cost after iteration 1037: 0.187429
# Cost after iteration 1038: 0.187375
# Cost after iteration 1039: 0.187322
# Cost after iteration 1040: 0.187270
# Cost after iteration 1041: 0.187219
# Cost after iteration 1042: 0.187169
# Cost after iteration 1043: 0.187121
# Cost after iteration 1044: 0.187073
# Cost after iteration 1045: 0.187026
# Cost after iteration 1046: 0.186980
# Cost after iteration 1047: 0.186935
# Cost after iteration 1048: 0.186890
# Cost after iteration 1049: 0.186847
# Cost after iteration 1050: 0.186804
# Cost after iteration 1051: 0.186762
# Cost after iteration 1052: 0.186721
# Cost after iteration 1053: 0.186680
# Cost after iteration 1054: 0.186641
# Cost after iteration 1055: 0.186601
# Cost after iteration 1056: 0.186563
# Cost after iteration 1057: 0.186525
# Cost after iteration 1058: 0.186488
# Cost after iteration 1059: 0.186451
# Cost after iteration 1060: 0.186415
# Cost after iteration 1061: 0.186381
# Cost after iteration 1062: 0.186348
# Cost after iteration 1063: 0.186318
# Cost after iteration 1064: 0.186293
# Cost after iteration 1065: 0.186280
# Cost after iteration 1066: 0.186292
# Cost after iteration 1067: 0.186358
# Cost after iteration 1068: 0.186537
# Cost after iteration 1069: 0.186981
# Cost after iteration 1070: 0.187978
# Cost after iteration 1071: 0.190375
# Cost after iteration 1072: 0.195606
# Cost after iteration 1073: 0.209721
# Cost after iteration 1074: 0.243086
# Cost after iteration 1075: 0.368614
# Cost after iteration 1076: 0.534743
# Cost after iteration 1077: 0.890058
# Cost after iteration 1078: 0.381884
# Cost after iteration 1079: 0.595153
# Cost after iteration 1080: 0.213942
# Cost after iteration 1081: 0.205603
# Cost after iteration 1082: 0.200313
# Cost after iteration 1083: 0.198227
# Cost after iteration 1084: 0.197007
# Cost after iteration 1085: 0.196238
# Cost after iteration 1086: 0.195642
# Cost after iteration 1087: 0.195138
# Cost after iteration 1088: 0.194686
# Cost after iteration 1089: 0.194270
# Cost after iteration 1090: 0.193882
# Cost after iteration 1091: 0.193518
# Cost after iteration 1092: 0.193175
# Cost after iteration 1093: 0.192851
# Cost after iteration 1094: 0.192545
# Cost after iteration 1095: 0.192256
# Cost after iteration 1096: 0.191982
# Cost after iteration 1097: 0.191723
# Cost after iteration 1098: 0.191477
# Cost after iteration 1099: 0.191243
# Cost after iteration 1100: 0.191022
# Cost after iteration 1101: 0.190811
# Cost after iteration 1102: 0.190611
# Cost after iteration 1103: 0.190420
# Cost after iteration 1104: 0.190238
# Cost after iteration 1105: 0.190065
# Cost after iteration 1106: 0.189900
# Cost after iteration 1107: 0.189742
# Cost after iteration 1108: 0.189592
# Cost after iteration 1109: 0.189448
# Cost after iteration 1110: 0.189310
# Cost after iteration 1111: 0.189179
# Cost after iteration 1112: 0.189052
# Cost after iteration 1113: 0.188932
# Cost after iteration 1114: 0.188816
# Cost after iteration 1115: 0.188704
# Cost after iteration 1116: 0.188597
# Cost after iteration 1117: 0.188495
# Cost after iteration 1118: 0.188396
# Cost after iteration 1119: 0.188301
# Cost after iteration 1120: 0.188209
# Cost after iteration 1121: 0.188121
# Cost after iteration 1122: 0.188036
# Cost after iteration 1123: 0.187954
# Cost after iteration 1124: 0.187875
# Cost after iteration 1125: 0.187798
# Cost after iteration 1126: 0.187724
# Cost after iteration 1127: 0.187653
# Cost after iteration 1128: 0.187583
# Cost after iteration 1129: 0.187516
# Cost after iteration 1130: 0.187451
# Cost after iteration 1131: 0.187388
# Cost after iteration 1132: 0.187327
# Cost after iteration 1133: 0.187268
# Cost after iteration 1134: 0.187210
# Cost after iteration 1135: 0.187154
# Cost after iteration 1136: 0.187100
# Cost after iteration 1137: 0.187047
# Cost after iteration 1138: 0.186995
# Cost after iteration 1139: 0.186945
# Cost after iteration 1140: 0.186896
# Cost after iteration 1141: 0.186849
# Cost after iteration 1142: 0.186802
# Cost after iteration 1143: 0.186757
# Cost after iteration 1144: 0.186713
# Cost after iteration 1145: 0.186670
# Cost after iteration 1146: 0.186628
# Cost after iteration 1147: 0.186588
# Cost after iteration 1148: 0.186549
# Cost after iteration 1149: 0.186513
# Cost after iteration 1150: 0.186479
# Cost after iteration 1151: 0.186450
# Cost after iteration 1152: 0.186428
# Cost after iteration 1153: 0.186418
# Cost after iteration 1154: 0.186430
# Cost after iteration 1155: 0.186481
# Cost after iteration 1156: 0.186598
# Cost after iteration 1157: 0.186851
# Cost after iteration 1158: 0.187326
# Cost after iteration 1159: 0.188292
# Cost after iteration 1160: 0.190030
# Cost after iteration 1161: 0.193746
# Cost after iteration 1162: 0.200354
# Cost after iteration 1163: 0.216879
# Cost after iteration 1164: 0.248250
# Cost after iteration 1165: 0.357477
# Cost after iteration 1166: 0.480677
# Cost after iteration 1167: 0.824462
# Cost after iteration 1168: 0.400691
# Cost after iteration 1169: 0.539812
# Cost after iteration 1170: 0.246844
# Cost after iteration 1171: 0.224746
# Cost after iteration 1172: 0.205428
# Cost after iteration 1173: 0.199762
# Cost after iteration 1174: 0.197062
# Cost after iteration 1175: 0.195875
# Cost after iteration 1176: 0.195170
# Cost after iteration 1177: 0.194672
# Cost after iteration 1178: 0.194259
# Cost after iteration 1179: 0.193890
# Cost after iteration 1180: 0.193549
# Cost after iteration 1181: 0.193228
# Cost after iteration 1182: 0.192926
# Cost after iteration 1183: 0.192639
# Cost after iteration 1184: 0.192367
# Cost after iteration 1185: 0.192109
# Cost after iteration 1186: 0.191863
# Cost after iteration 1187: 0.191629
# Cost after iteration 1188: 0.191406
# Cost after iteration 1189: 0.191193
# Cost after iteration 1190: 0.190991
# Cost after iteration 1191: 0.190797
# Cost after iteration 1192: 0.190613
# Cost after iteration 1193: 0.190436
# Cost after iteration 1194: 0.190268
# Cost after iteration 1195: 0.190107
# Cost after iteration 1196: 0.189952
# Cost after iteration 1197: 0.189804
# Cost after iteration 1198: 0.189663
# Cost after iteration 1199: 0.189527
# Cost after iteration 1200: 0.189397
# Cost after iteration 1201: 0.189272
# Cost after iteration 1202: 0.189152
# Cost after iteration 1203: 0.189037
# Cost after iteration 1204: 0.188926
# Cost after iteration 1205: 0.188819
# Cost after iteration 1206: 0.188716
# Cost after iteration 1207: 0.188617
# Cost after iteration 1208: 0.188522
# Cost after iteration 1209: 0.188430
# Cost after iteration 1210: 0.188341
# Cost after iteration 1211: 0.188256
# Cost after iteration 1212: 0.188173
# Cost after iteration 1213: 0.188093
# Cost after iteration 1214: 0.188016
# Cost after iteration 1215: 0.187941
# Cost after iteration 1216: 0.187869
# Cost after iteration 1217: 0.187799
# Cost after iteration 1218: 0.187731
# Cost after iteration 1219: 0.187665
# Cost after iteration 1220: 0.187601
# Cost after iteration 1221: 0.187540
# Cost after iteration 1222: 0.187479
# Cost after iteration 1223: 0.187421
# Cost after iteration 1224: 0.187364
# Cost after iteration 1225: 0.187309
# Cost after iteration 1226: 0.187255
# Cost after iteration 1227: 0.187203
# Cost after iteration 1228: 0.187152
# Cost after iteration 1229: 0.187103
# Cost after iteration 1230: 0.187054
# Cost after iteration 1231: 0.187007
# Cost after iteration 1232: 0.186961
# Cost after iteration 1233: 0.186917
# Cost after iteration 1234: 0.186873
# Cost after iteration 1235: 0.186830
# Cost after iteration 1236: 0.186788
# Cost after iteration 1237: 0.186747
# Cost after iteration 1238: 0.186708
# Cost after iteration 1239: 0.186668
# Cost after iteration 1240: 0.186630
# Cost after iteration 1241: 0.186593
# Cost after iteration 1242: 0.186556
# Cost after iteration 1243: 0.186520
# Cost after iteration 1244: 0.186485
# Cost after iteration 1245: 0.186451
# Cost after iteration 1246: 0.186417
# Cost after iteration 1247: 0.186384
# Cost after iteration 1248: 0.186351
# Cost after iteration 1249: 0.186319
# Cost after iteration 1250: 0.186288
# Cost after iteration 1251: 0.186258
# Cost after iteration 1252: 0.186228
# Cost after iteration 1253: 0.186200
# Cost after iteration 1254: 0.186172
# Cost after iteration 1255: 0.186147
# Cost after iteration 1256: 0.186125
# Cost after iteration 1257: 0.186109
# Cost after iteration 1258: 0.186101
# Cost after iteration 1259: 0.186110
# Cost after iteration 1260: 0.186147
# Cost after iteration 1261: 0.186240
# Cost after iteration 1262: 0.186428
# Cost after iteration 1263: 0.186816
# Cost after iteration 1264: 0.187525
# Cost after iteration 1265: 0.189000
# Cost after iteration 1266: 0.191599
# Cost after iteration 1267: 0.197470
# Cost after iteration 1268: 0.207576
# Cost after iteration 1269: 0.235243
# Cost after iteration 1270: 0.283721
# Cost after iteration 1271: 0.467638
# Cost after iteration 1272: 0.601542
# Cost after iteration 1273: 1.378706
# Cost after iteration 1274: 0.208256
# Cost after iteration 1275: 0.203029
# Cost after iteration 1276: 0.201029
# Cost after iteration 1277: 0.200006
# Cost after iteration 1278: 0.199189
# Cost after iteration 1279: 0.198460
# Cost after iteration 1280: 0.197787
# Cost after iteration 1281: 0.197162
# Cost after iteration 1282: 0.196579
# Cost after iteration 1283: 0.196034
# Cost after iteration 1284: 0.195523
# Cost after iteration 1285: 0.195045
# Cost after iteration 1286: 0.194595
# Cost after iteration 1287: 0.194173
# Cost after iteration 1288: 0.193776
# Cost after iteration 1289: 0.193403
# Cost after iteration 1290: 0.193050
# Cost after iteration 1291: 0.192719
# Cost after iteration 1292: 0.192405
# Cost after iteration 1293: 0.192110
# Cost after iteration 1294: 0.191830
# Cost after iteration 1295: 0.191566
# Cost after iteration 1296: 0.191317
# Cost after iteration 1297: 0.191080
# Cost after iteration 1298: 0.190856
# Cost after iteration 1299: 0.190644
# Cost after iteration 1300: 0.190442
# Cost after iteration 1301: 0.190251
# Cost after iteration 1302: 0.190069
# Cost after iteration 1303: 0.189897
# Cost after iteration 1304: 0.189733
# Cost after iteration 1305: 0.189577
# Cost after iteration 1306: 0.189428
# Cost after iteration 1307: 0.189286
# Cost after iteration 1308: 0.189151
# Cost after iteration 1309: 0.189023
# Cost after iteration 1310: 0.188900
# Cost after iteration 1311: 0.188782
# Cost after iteration 1312: 0.188670
# Cost after iteration 1313: 0.188563
# Cost after iteration 1314: 0.188460
# Cost after iteration 1315: 0.188362
# Cost after iteration 1316: 0.188268
# Cost after iteration 1317: 0.188178
# Cost after iteration 1318: 0.188091
# Cost after iteration 1319: 0.188008
# Cost after iteration 1320: 0.187928
# Cost after iteration 1321: 0.187851
# Cost after iteration 1322: 0.187777
# Cost after iteration 1323: 0.187706
# Cost after iteration 1324: 0.187637
# Cost after iteration 1325: 0.187571
# Cost after iteration 1326: 0.187507
# Cost after iteration 1327: 0.187446
# Cost after iteration 1328: 0.187387
# Cost after iteration 1329: 0.187329
# Cost after iteration 1330: 0.187274
# Cost after iteration 1331: 0.187220
# Cost after iteration 1332: 0.187168
# Cost after iteration 1333: 0.187118
# Cost after iteration 1334: 0.187069
# Cost after iteration 1335: 0.187021
# Cost after iteration 1336: 0.186975
# Cost after iteration 1337: 0.186931
# Cost after iteration 1338: 0.186887
# Cost after iteration 1339: 0.186845
# Cost after iteration 1340: 0.186804
# Cost after iteration 1341: 0.186764
# Cost after iteration 1342: 0.186725
# Cost after iteration 1343: 0.186688
# Cost after iteration 1344: 0.186651
# Cost after iteration 1345: 0.186615
# Cost after iteration 1346: 0.186580
# Cost after iteration 1347: 0.186545
# Cost after iteration 1348: 0.186512
# Cost after iteration 1349: 0.186479
# Cost after iteration 1350: 0.186447
# Cost after iteration 1351: 0.186416
# Cost after iteration 1352: 0.186385
# Cost after iteration 1353: 0.186355
# Cost after iteration 1354: 0.186326
# Cost after iteration 1355: 0.186297
# Cost after iteration 1356: 0.186269
# Cost after iteration 1357: 0.186241
# Cost after iteration 1358: 0.186214
# Cost after iteration 1359: 0.186187
# Cost after iteration 1360: 0.186161
# Cost after iteration 1361: 0.186135
# Cost after iteration 1362: 0.186110
# Cost after iteration 1363: 0.186085
# ...
# Cost after iteration 2560: 0.188366
# Cost after iteration 2561: 0.188302
# Cost after iteration 2562: 0.188241
# Cost after iteration 2563: 0.188182
# Cost after iteration 2564: 0.188125
# Cost after iteration 2565: 0.188069
# Cost after iteration 2566: 0.188015
# Cost after iteration 2567: 0.187963
# Cost after iteration 2568: 0.187913
# Cost after iteration 2569: 0.187864
# Cost after iteration 2570: 0.187816
# Cost after iteration 2571: 0.187770
# Cost after iteration 2572: 0.187725
# Cost after iteration 2573: 0.187682
# Cost after iteration 2574: 0.187639
# Cost after iteration 2575: 0.187598
# Cost after iteration 2576: 0.187559
# Cost after iteration 2577: 0.187520
# Cost after iteration 2578: 0.187482
# Cost after iteration 2579: 0.187446
# Cost after iteration 2580: 0.187411
# Cost after iteration 2581: 0.187377
# Cost after iteration 2582: 0.187344
# Cost after iteration 2583: 0.187313
# Cost after iteration 2584: 0.187284
# Cost after iteration 2585: 0.187256
# Cost after iteration 2586: 0.187231
# Cost after iteration 2587: 0.187209
# Cost after iteration 2588: 0.187192
# Cost after iteration 2589: 0.187179
# Cost after iteration 2590: 0.187177
# Cost after iteration 2591: 0.187182
# Cost after iteration 2592: 0.187209
# Cost after iteration 2593: 0.187250
# Cost after iteration 2594: 0.187345
# Cost after iteration 2595: 0.187462
# Cost after iteration 2596: 0.187718
# Cost after iteration 2597: 0.188009
# Cost after iteration 2598: 0.188675
# Cost after iteration 2599: 0.189380
# Cost after iteration 2600: 0.191189
# Cost after iteration 2601: 0.192975
# Cost after iteration 2602: 0.198283
# Cost after iteration 2603: 0.203028
# Cost after iteration 2604: 0.219247
# Cost after iteration 2605: 0.226299
# Cost after iteration 2606: 0.267962
# Cost after iteration 2607: 0.249824
# Cost after iteration 2608: 0.304866
# Cost after iteration 2609: 0.244337
# Cost after iteration 2610: 0.266369
# Cost after iteration 2611: 0.222264
# Cost after iteration 2612: 0.226602
# Cost after iteration 2613: 0.215266
# Cost after iteration 2614: 0.218630
# Cost after iteration 2615: 0.215122
# Cost after iteration 2616: 0.220302
# Cost after iteration 2617: 0.219370
# Cost after iteration 2618: 0.227941
# Cost after iteration 2619: 0.226961
# Cost after iteration 2620: 0.239296
# Cost after iteration 2621: 0.234579
# Cost after iteration 2622: 0.247171
# Cost after iteration 2623: 0.235011
# Cost after iteration 2624: 0.240053
# Cost after iteration 2625: 0.223987
# Cost after iteration 2626: 0.219327
# Cost after iteration 2627: 0.207414
# Cost after iteration 2628: 0.201247
# Cost after iteration 2629: 0.195783
# Cost after iteration 2630: 0.193089
# Cost after iteration 2631: 0.191331
# Cost after iteration 2632: 0.190464
# Cost after iteration 2633: 0.189891
# Cost after iteration 2634: 0.189566
# Cost after iteration 2635: 0.189318
# Cost after iteration 2636: 0.189150
# Cost after iteration 2637: 0.189004
# Cost after iteration 2638: 0.188889
# Cost after iteration 2639: 0.188784
# Cost after iteration 2640: 0.188693
# Cost after iteration 2641: 0.188607
# Cost after iteration 2642: 0.188529
# Cost after iteration 2643: 0.188455
# Cost after iteration 2644: 0.188386
# Cost after iteration 2645: 0.188319
# Cost after iteration 2646: 0.188256
# Cost after iteration 2647: 0.188195
# Cost after iteration 2648: 0.188137
# Cost after iteration 2649: 0.188081
# Cost after iteration 2650: 0.188028
# Cost after iteration 2651: 0.187976
# Cost after iteration 2652: 0.187926
# Cost after iteration 2653: 0.187877
# Cost after iteration 2654: 0.187831
# Cost after iteration 2655: 0.187786
# Cost after iteration 2656: 0.187743
# Cost after iteration 2657: 0.187701
# Cost after iteration 2658: 0.187662
# Cost after iteration 2659: 0.187623
# Cost after iteration 2660: 0.187587
# Cost after iteration 2661: 0.187552
# Cost after iteration 2662: 0.187519
# Cost after iteration 2663: 0.187488
# Cost after iteration 2664: 0.187462
# Cost after iteration 2665: 0.187436
# Cost after iteration 2666: 0.187417
# Cost after iteration 2667: 0.187399
# Cost after iteration 2668: 0.187392
# Cost after iteration 2669: 0.187387
# Cost after iteration 2670: 0.187402
# Cost after iteration 2671: 0.187419
# Cost after iteration 2672: 0.187474
# Cost after iteration 2673: 0.187532
# Cost after iteration 2674: 0.187671
# Cost after iteration 2675: 0.187807
# Cost after iteration 2676: 0.188126
# Cost after iteration 2677: 0.188422
# Cost after iteration 2678: 0.189155
# Cost after iteration 2679: 0.189795
# Cost after iteration 2680: 0.191563
# Cost after iteration 2681: 0.193017
# Cost after iteration 2682: 0.197590
# Cost after iteration 2683: 0.201026
# Cost after iteration 2684: 0.213343
# Cost after iteration 2685: 0.218572
# Cost after iteration 2686: 0.247661
# Cost after iteration 2687: 0.237488
# Cost after iteration 2688: 0.278349
# Cost after iteration 2689: 0.238975
# Cost after iteration 2690: 0.263104
# Cost after iteration 2691: 0.224206
# Cost after iteration 2692: 0.231270
# Cost after iteration 2693: 0.216162
# Cost after iteration 2694: 0.219912
# Cost after iteration 2695: 0.214224
# Cost after iteration 2696: 0.218236
# Cost after iteration 2697: 0.215903
# Cost after iteration 2698: 0.221739
# Cost after iteration 2699: 0.220559
# Cost after iteration 2700: 0.229087
# Cost after iteration 2701: 0.226876
# Cost after iteration 2702: 0.237324
# Cost after iteration 2703: 0.231125
# Cost after iteration 2704: 0.239364
# Cost after iteration 2705: 0.227898
# Cost after iteration 2706: 0.228757
# Cost after iteration 2707: 0.216162
# Cost after iteration 2708: 0.210940
# Cost after iteration 2709: 0.202388
# Cost after iteration 2710: 0.197869
# Cost after iteration 2711: 0.194083
# Cost after iteration 2712: 0.192198
# Cost after iteration 2713: 0.190875
# Cost after iteration 2714: 0.190196
# Cost after iteration 2715: 0.189694
# Cost after iteration 2716: 0.189405
# Cost after iteration 2717: 0.189163
# Cost after iteration 2718: 0.189002
# Cost after iteration 2719: 0.188854
# Cost after iteration 2720: 0.188743
# Cost after iteration 2721: 0.188637
# Cost after iteration 2722: 0.188550
# Cost after iteration 2723: 0.188465
# Cost after iteration 2724: 0.188391
# Cost after iteration 2725: 0.188319
# Cost after iteration 2726: 0.188255
# Cost after iteration 2727: 0.188191
# Cost after iteration 2728: 0.188133
# Cost after iteration 2729: 0.188076
# Cost after iteration 2730: 0.188024
# Cost after iteration 2731: 0.187972
# Cost after iteration 2732: 0.187924
# Cost after iteration 2733: 0.187877
# Cost after iteration 2734: 0.187833
# Cost after iteration 2735: 0.187790
# Cost after iteration 2736: 0.187752
# Cost after iteration 2737: 0.187713
# Cost after iteration 2738: 0.187679
# Cost after iteration 2739: 0.187645
# Cost after iteration 2740: 0.187618
# Cost after iteration 2741: 0.187589
# Cost after iteration 2742: 0.187570
# Cost after iteration 2743: 0.187550
# Cost after iteration 2744: 0.187543
# Cost after iteration 2745: 0.187535
# Cost after iteration 2746: 0.187549
# Cost after iteration 2747: 0.187559
# Cost after iteration 2748: 0.187610
# Cost after iteration 2749: 0.187652
# Cost after iteration 2750: 0.187771
# Cost after iteration 2751: 0.187871
# Cost after iteration 2752: 0.188126
# Cost after iteration 2753: 0.188335
# Cost after iteration 2754: 0.188877
# Cost after iteration 2755: 0.189303
# Cost after iteration 2756: 0.190499
# Cost after iteration 2757: 0.191391
# Cost after iteration 2758: 0.194191
# Cost after iteration 2759: 0.196165
# Cost after iteration 2760: 0.203134
# Cost after iteration 2761: 0.207128
# Cost after iteration 2762: 0.224084
# Cost after iteration 2763: 0.225045
# Cost after iteration 2764: 0.256652
# Cost after iteration 2765: 0.236132
# Cost after iteration 2766: 0.267138
# Cost after iteration 2767: 0.229895
# Cost after iteration 2768: 0.243705
# Cost after iteration 2769: 0.218938
# Cost after iteration 2770: 0.224134
# Cost after iteration 2771: 0.214250
# Cost after iteration 2772: 0.217752
# Cost after iteration 2773: 0.213265
# Cost after iteration 2774: 0.217121
# Cost after iteration 2775: 0.214973
# Cost after iteration 2776: 0.220258
# Cost after iteration 2777: 0.218797
# Cost after iteration 2778: 0.225887
# Cost after iteration 2779: 0.223375
# Cost after iteration 2780: 0.231248
# Cost after iteration 2781: 0.225728
# Cost after iteration 2782: 0.231247
# Cost after iteration 2783: 0.222216
# Cost after iteration 2784: 0.222178
# Cost after iteration 2785: 0.212408
# Cost after iteration 2786: 0.208152
# Cost after iteration 2787: 0.201191
# Cost after iteration 2788: 0.197463
# Cost after iteration 2789: 0.194075
# Cost after iteration 2790: 0.192322
# Cost after iteration 2791: 0.190980
# Cost after iteration 2792: 0.190272
# Cost after iteration 2793: 0.189715
# Cost after iteration 2794: 0.189398
# Cost after iteration 2795: 0.189123
# Cost after iteration 2796: 0.188949
# Cost after iteration 2797: 0.188785
# Cost after iteration 2798: 0.188670
# Cost after iteration 2799: 0.188555
# Cost after iteration 2800: 0.188469
# Cost after iteration 2801: 0.188380
# Cost after iteration 2802: 0.188309
# Cost after iteration 2803: 0.188236
# Cost after iteration 2804: 0.188175
# Cost after iteration 2805: 0.188112
# Cost after iteration 2806: 0.188059
# Cost after iteration 2807: 0.188004
# Cost after iteration 2808: 0.187957
# Cost after iteration 2809: 0.187907
# Cost after iteration 2810: 0.187866
# Cost after iteration 2811: 0.187822
# Cost after iteration 2812: 0.187787
# Cost after iteration 2813: 0.187748
# Cost after iteration 2814: 0.187719
# Cost after iteration 2815: 0.187687
# Cost after iteration 2816: 0.187667
# Cost after iteration 2817: 0.187642
# Cost after iteration 2818: 0.187633
# Cost after iteration 2819: 0.187618
# Cost after iteration 2820: 0.187626
# Cost after iteration 2821: 0.187626
# Cost after iteration 2822: 0.187664
# Cost after iteration 2823: 0.187688
# Cost after iteration 2824: 0.187776
# Cost after iteration 2825: 0.187840
# Cost after iteration 2826: 0.188023
# Cost after iteration 2827: 0.188158
# Cost after iteration 2828: 0.188527
# Cost after iteration 2829: 0.188795
# Cost after iteration 2830: 0.189553
# Cost after iteration 2831: 0.190083
# Cost after iteration 2832: 0.191718
# Cost after iteration 2833: 0.192811
# Cost after iteration 2834: 0.196559
# Cost after iteration 2835: 0.198890
# Cost after iteration 2836: 0.207858
# Cost after iteration 2837: 0.211585
# Cost after iteration 2838: 0.231390
# Cost after iteration 2839: 0.227643
# Cost after iteration 2840: 0.258083
# Cost after iteration 2841: 0.233378
# Cost after iteration 2842: 0.257410
# Cost after iteration 2843: 0.225549
# Cost after iteration 2844: 0.235865
# Cost after iteration 2845: 0.218119
# Cost after iteration 2846: 0.223298
# Cost after iteration 2847: 0.215624
# Cost after iteration 2848: 0.220120
# Cost after iteration 2849: 0.216594
# Cost after iteration 2850: 0.222378
# Cost after iteration 2851: 0.220745
# Cost after iteration 2852: 0.229277
# Cost after iteration 2853: 0.227569
# Cost after iteration 2854: 0.239206
# Cost after iteration 2855: 0.234155
# Cost after iteration 2856: 0.245638
# Cost after iteration 2857: 0.234033
# Cost after iteration 2858: 0.238422
# Cost after iteration 2859: 0.223356
# Cost after iteration 2860: 0.218878
# Cost after iteration 2861: 0.207478
# Cost after iteration 2862: 0.201625
# Cost after iteration 2863: 0.196182
# Cost after iteration 2864: 0.193529
# Cost after iteration 2865: 0.191645
# Cost after iteration 2866: 0.190742
# Cost after iteration 2867: 0.190072
# Cost after iteration 2868: 0.189715
# Cost after iteration 2869: 0.189409
# Cost after iteration 2870: 0.189222
# Cost after iteration 2871: 0.189043
# Cost after iteration 2872: 0.188918
# Cost after iteration 2873: 0.188794
# Cost after iteration 2874: 0.188698
# Cost after iteration 2875: 0.188602
# Cost after iteration 2876: 0.188522
# Cost after iteration 2877: 0.188442
# Cost after iteration 2878: 0.188372
# Cost after iteration 2879: 0.188303
# Cost after iteration 2880: 0.188241
# Cost after iteration 2881: 0.188179
# Cost after iteration 2882: 0.188123
# Cost after iteration 2883: 0.188067
# Cost after iteration 2884: 0.188017
# Cost after iteration 2885: 0.187966
# Cost after iteration 2886: 0.187920
# Cost after iteration 2887: 0.187874
# Cost after iteration 2888: 0.187832
# Cost after iteration 2889: 0.187791
# Cost after iteration 2890: 0.187754
# Cost after iteration 2891: 0.187718
# Cost after iteration 2892: 0.187687
# Cost after iteration 2893: 0.187656
# Cost after iteration 2894: 0.187634
# Cost after iteration 2895: 0.187610
# Cost after iteration 2896: 0.187599
# Cost after iteration 2897: 0.187585
# Cost after iteration 2898: 0.187592
# Cost after iteration 2899: 0.187595
# Cost after iteration 2900: 0.187633
# Cost after iteration 2901: 0.187663
# Cost after iteration 2902: 0.187757
# Cost after iteration 2903: 0.187834
# Cost after iteration 2904: 0.188037
# Cost after iteration 2905: 0.188200
# Cost after iteration 2906: 0.188627
# Cost after iteration 2907: 0.188958
# Cost after iteration 2908: 0.189876
# Cost after iteration 2909: 0.190555
# Cost after iteration 2910: 0.192636
# Cost after iteration 2911: 0.194098
# Cost after iteration 2912: 0.199125
# Cost after iteration 2913: 0.202276
# Cost after iteration 2914: 0.214669
# Cost after iteration 2915: 0.218190
# Cost after iteration 2916: 0.244292
# Cost after iteration 2917: 0.233020
# Cost after iteration 2918: 0.265937
# Cost after iteration 2919: 0.232718
# Cost after iteration 2920: 0.251993
# Cost after iteration 2921: 0.221266
# Cost after iteration 2922: 0.227990
# Cost after iteration 2923: 0.214324
# Cost after iteration 2924: 0.217674
# Cost after iteration 2925: 0.211514
# Cost after iteration 2926: 0.214289
# Cost after iteration 2927: 0.211218
# Cost after iteration 2928: 0.214510
# Cost after iteration 2929: 0.212777
# Cost after iteration 2930: 0.217022
# Cost after iteration 2931: 0.215357
# Cost after iteration 2932: 0.220272
# Cost after iteration 2933: 0.217497
# Cost after iteration 2934: 0.221860
# Cost after iteration 2935: 0.217155
# Cost after iteration 2936: 0.219092
# Cost after iteration 2937: 0.212793
# Cost after iteration 2938: 0.211425
# Cost after iteration 2939: 0.205251
# Cost after iteration 2940: 0.202228
# Cost after iteration 2941: 0.197876
# Cost after iteration 2942: 0.195487
# Cost after iteration 2943: 0.193159
# Cost after iteration 2944: 0.191873
# Cost after iteration 2945: 0.190775
# Cost after iteration 2946: 0.190152
# Cost after iteration 2947: 0.189621
# Cost after iteration 2948: 0.189305
# Cost after iteration 2949: 0.189019
# Cost after iteration 2950: 0.188839
# Cost after iteration 2951: 0.188665
# Cost after iteration 2952: 0.188548
# Cost after iteration 2953: 0.188428
# Cost after iteration 2954: 0.188344
# Cost after iteration 2955: 0.188254
# Cost after iteration 2956: 0.188188
# Cost after iteration 2957: 0.188116
# Cost after iteration 2958: 0.188062
# Cost after iteration 2959: 0.188002
# Cost after iteration 2960: 0.187958
# Cost after iteration 2961: 0.187907
# Cost after iteration 2962: 0.187871
# Cost after iteration 2963: 0.187828
# Cost after iteration 2964: 0.187800
# Cost after iteration 2965: 0.187765
# Cost after iteration 2966: 0.187746
# Cost after iteration 2967: 0.187719
# Cost after iteration 2968: 0.187713
# Cost after iteration 2969: 0.187696
# Cost after iteration 2970: 0.187709
# Cost after iteration 2971: 0.187706
# Cost after iteration 2972: 0.187747
# Cost after iteration 2973: 0.187765
# Cost after iteration 2974: 0.187853
# Cost after iteration 2975: 0.187905
# Cost after iteration 2976: 0.188077
# Cost after iteration 2977: 0.188186
# Cost after iteration 2978: 0.188512
# Cost after iteration 2979: 0.188722
# Cost after iteration 2980: 0.189354
# Cost after iteration 2981: 0.189753
# Cost after iteration 2982: 0.191027
# Cost after iteration 2983: 0.191807
# Cost after iteration 2984: 0.194523
# Cost after iteration 2985: 0.196112
# Cost after iteration 2986: 0.202228
# Cost after iteration 2987: 0.205167
# Cost after iteration 2988: 0.218725
# Cost after iteration 2989: 0.219886
# Cost after iteration 2990: 0.244271
# Cost after iteration 2991: 0.230689
# Cost after iteration 2992: 0.256914
# Cost after iteration 2993: 0.229353
# Cost after iteration 2994: 0.244840
# Cost after iteration 2995: 0.223046
# Cost after iteration 2996: 0.231253
# Cost after iteration 2997: 0.221209
# Cost after iteration 2998: 0.228568
# Cost after iteration 2999: 0.224503
# W1 = [[ 2.0228133  -2.0288983 ]
#  [ 2.32102008 -1.77436509]]
# b1 = [[-4.84373845]
#  [ 6.30256776]]
# W2 = [[-7.208028    7.14201114]]
# b2 = [[-3.44244582]]

# %% [markdown]
# ##### __Expected Output__
# Note: the actual values can be different!
#
# ```Python
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# ...
# Cost after iteration 2995: 0.209524
# Cost after iteration 2996: 0.208025
# Cost after iteration 2997: 0.210427
# Cost after iteration 2998: 0.208929
# Cost after iteration 2999: 0.211306
# W1 = [[ 2.14274251 -1.93155541]
#  [ 2.20268789 -2.1131799 ]]
# b1 = [[-4.83079243]
#  [ 6.2845223 ]]
# W2 = [[-7.21370685  7.0898022 ]]
# b2 = [[-3.48755239]]
# ```

# %%
# Note: 
# Actual values are not checked here in the unit tests (due to random initialization).
w3_unittest.test_nn_model(nn_model)
# Out:
#  All tests passed

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.

# %% [markdown]
# <a name='ex08'></a>
# ### Exercise 8
#
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.

# %%
# GRADED FUNCTION: predict

def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    
    ### START CODE HERE ### (≈ 2 lines of code)
    A2, cache = forward_propagation(X, parameters)
    predictions = A2>0.5
    ### END CODE HERE ###
    
    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]

# %% [markdown]
# ##### __Expected Output__
#
# ```Python
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[ True  True False False]]
# ```

# %%
w3_unittest.test_predict(predict)
# Out:
#  All tests passed

# %% [markdown]
# Let's visualize the boundary line. Do not worry if you don't understand the function `plot_decision_boundary` line by line - it simply makes prediction for some points on the plane and plots them as a contour plot (just two colors - blue and red).

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# That's great, you can see that more complicated classification problems can be solved with two layer neural network!

# %% [markdown]
# <a name='4'></a>
# ## 4 - Optional: Other Dataset

# %% [markdown]
# Build a slightly different dataset:

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %% [markdown]
# Notice that when building your neural network, a number of the nodes in the hidden layer could be taken as a parameter. Try to change this parameter and investigate the results:

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
parameters_2 = nn_model(X_2, Y_2, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# You can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, you do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.

# %% [markdown]
# Congrats on finishing this programming assignment!
